# %%
#Showing directories’ size
import os, shutil

train_dir ='./images/train'
validation_dir = './images/val'
test_dir = './images/test'

train_corona_virus_d = './images/train/Corona_Virus_Disease'
train_normal = './images/train/Normal'
train_tuberculosis= './images/train/Tuberculosis'

val_corona_virus_d = './images/val/Corona_Virus_Disease'
val_normal = './images/val/Normal'
val_tuberculosis= './images/val/Tuberculosis'

test_corona_virus_d = './images/test/Corona_Virus_Disease'
test_normal = './images/test/Normal'
test_tuberculosis= './images/test/Tuberculosis'


print('total train corona virus images:', len(os.listdir(train_corona_virus_d)))
print('total train normal images:', len(os.listdir(train_normal)))
print('total train tuberculosis images:', len(os.listdir(train_tuberculosis)))


print('total validation corona virus images:', len(os.listdir(val_corona_virus_d)))
print('total validation normal images:', len(os.listdir(val_normal)))
print('total validation tuberculosis images:', len(os.listdir(val_tuberculosis)))


print('total testing organic corona virus img:', len(os.listdir(test_corona_virus_d)))
print('total testing recicle normal imgs:', len(os.listdir(test_normal)))
print('total testing recicle tuberculosis img:', len(os.listdir(test_tuberculosis)))
# Out:
# total train corona virus images: 1218
# total train normal images: 1207
# total train tuberculosis images: 1220
# total validation corona virus images: 406
# total validation normal images: 402
# total validation tuberculosis images: 406
# total testing organic corona virus img: 407
# total testing recicle normal imgs: 404
# total testing recicle tuberculosis img: 408

# %%
import tensorflow as tf
from keras.utils import image_dataset_from_directory

IMG_SIZE = 150
train_dataset = image_dataset_from_directory(
    train_dir,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=32,
    label_mode='categorical',
    seed = 100
)

validation_dataset = image_dataset_from_directory(
    validation_dir,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=64,
    label_mode='categorical',
    seed = 100
)

test_dataset = image_dataset_from_directory(
    test_dir,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=64,
    label_mode='categorical',
    seed = 100
)
# Out:
# Found 3645 files belonging to 3 classes.
# Found 1214 files belonging to 3 classes.
# Found 1219 files belonging to 3 classes.

# %%
#Viewing the first 5 images of the first batch
import matplotlib.pyplot as plt
for data_batch, _ in train_dataset.take(1):
    for i in range(5):
        plt.imshow(data_batch[i].numpy().astype("uint8"))
        plt.show()

# %%
from tensorflow import keras
from keras import layers
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal_and_vertical"),
        layers.RandomRotation(0.2),
        layers.RandomZoom(0.3),
        layers.RandomBrightness(0.4, value_range = (0, 255)),
        layers.RandomContrast(0.1),
        layers.RandomTranslation(0.1,0.2)
    
    ]
)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
  for i in range(4):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(2, 2, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
from tensorflow import keras
from keras import layers
from keras import models
inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(inputs)
# x = layers.Conv2D(filters=32, kernel_size=12, activation="relu")(x)
# x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=32, kernel_size=7, activation="relu")(x)
x = layers.BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001, center=True, scale=True)(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=64, kernel_size=5, activation="relu")(x)
x = layers.BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001, center=True, scale=True)(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=128, kernel_size=5, activation="relu")(x)
x = layers.BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001, center=True, scale=True)(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001, center=True, scale=True)(x)
x = layers.MaxPooling2D(pool_size=2)(x)

# x = layers.Conv2D(filters=512, kernel_size=3, activation="relu")(x)
# x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(2048, activation="relu")(x)
x = layers.BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001, center=True, scale=True)(x)

outputs = layers.Dense(3, activation="softmax")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 150, 150, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 150, 150, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 144, 144, 32)   │         4,736 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 144, 144, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 72, 72, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 68, 68, 64)     │        51,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 68, 68, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 34, 34, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 30, 30, 128)    │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 30, 30, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 15, 15, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 13, 13, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 13, 13, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 2048)           │    18,876,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 2048)           │         8,192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │         6,147 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,448,771 (74.19 MB)
#  Trainable params: 19,443,715 (74.17 MB)
#  Non-trainable params: 5,056 (19.75 KB)

# %%
import tensorflow as tf
model.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-8),
    metrics=['acc'])

# %%
callbacks_list = [
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=10),
    keras.callbacks.ModelCheckpoint(filepath="best_model.keras", save_best_only=True,monitor='val_loss')
]

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"
import keras

# %%
history = model.fit(
    train_dataset,
    epochs=250,
    validation_data=validation_dataset,
    verbose=1,
    callbacks=callbacks_list
)
# Out:
# Epoch 1/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 102s 869ms/step - acc: 0.3371 - loss: 1.5699 - val_acc: 0.3344 - val_loss: 1.1329
# Epoch 2/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 100s 875ms/step - acc: 0.3497 - loss: 1.5061 - val_acc: 0.2644 - val_loss: 1.1623
# Epoch 3/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 832ms/step - acc: 0.3561 - loss: 1.5163 - val_acc: 0.3147 - val_loss: 1.1762
# Epoch 4/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 828ms/step - acc: 0.3645 - loss: 1.4510 - val_acc: 0.3550 - val_loss: 1.1644
# Epoch 5/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 829ms/step - acc: 0.3655 - loss: 1.5003 - val_acc: 0.3871 - val_loss: 1.1341
# Epoch 6/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 97s 851ms/step - acc: 0.3761 - loss: 1.4242 - val_acc: 0.3995 - val_loss: 1.1081
# Epoch 7/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 100s 879ms/step - acc: 0.3819 - loss: 1.4107 - val_acc: 0.4308 - val_loss: 1.0877
# Epoch 8/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 824ms/step - acc: 0.3868 - loss: 1.4108 - val_acc: 0.4399 - val_loss: 1.0726
# Epoch 9/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 96s 839ms/step - acc: 0.4095 - loss: 1.3510 - val_acc: 0.4572 - val_loss: 1.0574
# Epoch 10/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 830ms/step - acc: 0.4089 - loss: 1.3363 - val_acc: 0.4753 - val_loss: 1.0382
# Epoch 11/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 835ms/step - acc: 0.4159 - loss: 1.3466 - val_acc: 0.4893 - val_loss: 1.0234
# Epoch 12/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 833ms/step - acc: 0.4129 - loss: 1.3306 - val_acc: 0.5099 - val_loss: 1.0027
# Epoch 13/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 832ms/step - acc: 0.4507 - loss: 1.2912 - val_acc: 0.5288 - val_loss: 0.9853
# Epoch 14/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 833ms/step - acc: 0.4336 - loss: 1.2785 - val_acc: 0.5461 - val_loss: 0.9683
# Epoch 15/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 831ms/step - acc: 0.4469 - loss: 1.2580 - val_acc: 0.5568 - val_loss: 0.9566
# Epoch 16/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 825ms/step - acc: 0.4522 - loss: 1.2472 - val_acc: 0.5717 - val_loss: 0.9423
# Epoch 17/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 96s 841ms/step - acc: 0.4412 - loss: 1.2482 - val_acc: 0.5783 - val_loss: 0.9320
# Epoch 18/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 830ms/step - acc: 0.4611 - loss: 1.2068 - val_acc: 0.5898 - val_loss: 0.9164
# Epoch 19/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 826ms/step - acc: 0.4708 - loss: 1.2182 - val_acc: 0.5939 - val_loss: 0.9045
# Epoch 20/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 98s 859ms/step - acc: 0.4819 - loss: 1.1718 - val_acc: 0.6071 - val_loss: 0.8914
# Epoch 21/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 102s 897ms/step - acc: 0.4730 - loss: 1.1962 - val_acc: 0.6186 - val_loss: 0.8792
# Epoch 22/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 99s 871ms/step - acc: 0.4981 - loss: 1.1299 - val_acc: 0.6227 - val_loss: 0.8692
# Epoch 23/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 99s 870ms/step - acc: 0.4984 - loss: 1.1512 - val_acc: 0.6269 - val_loss: 0.8609
# Epoch 24/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 99s 870ms/step - acc: 0.5035 - loss: 1.1271 - val_acc: 0.6326 - val_loss: 0.8493
# Epoch 25/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 99s 868ms/step - acc: 0.5130 - loss: 1.1396 - val_acc: 0.6376 - val_loss: 0.8379
# Epoch 26/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 99s 871ms/step - acc: 0.5081 - loss: 1.0934 - val_acc: 0.6442 - val_loss: 0.8300
# Epoch 27/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 99s 871ms/step - acc: 0.5330 - loss: 1.0793 - val_acc: 0.6491 - val_loss: 0.8217
# Epoch 28/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 100s 878ms/step - acc: 0.5116 - loss: 1.0808 - val_acc: 0.6565 - val_loss: 0.8118
# Epoch 29/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 99s 869ms/step - acc: 0.5236 - loss: 1.1095 - val_acc: 0.6598 - val_loss: 0.8041
# Epoch 30/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 99s 869ms/step - acc: 0.5398 - loss: 1.0838 - val_acc: 0.6664 - val_loss: 0.7940
# Epoch 31/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 99s 868ms/step - acc: 0.5416 - loss: 1.0718 - val_acc: 0.6664 - val_loss: 0.7872
# Epoch 32/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 101s 890ms/step - acc: 0.5520 - loss: 1.0444 - val_acc: 0.6713 - val_loss: 0.7772
# Epoch 33/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 99s 870ms/step - acc: 0.5431 - loss: 1.0295 - val_acc: 0.6787 - val_loss: 0.7679
# Epoch 34/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 832ms/step - acc: 0.5354 - loss: 1.0834 - val_acc: 0.6763 - val_loss: 0.7596
# Epoch 35/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 828ms/step - acc: 0.5366 - loss: 1.0557 - val_acc: 0.6796 - val_loss: 0.7544
# Epoch 36/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 836ms/step - acc: 0.5730 - loss: 0.9808 - val_acc: 0.6812 - val_loss: 0.7484
# Epoch 37/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 98s 855ms/step - acc: 0.5634 - loss: 0.9979 - val_acc: 0.6853 - val_loss: 0.7400
# Epoch 38/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 100s 875ms/step - acc: 0.5758 - loss: 1.0042 - val_acc: 0.6886 - val_loss: 0.7334
# Epoch 39/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 99s 871ms/step - acc: 0.5838 - loss: 0.9965 - val_acc: 0.6895 - val_loss: 0.7284
# Epoch 40/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 99s 868ms/step - acc: 0.5856 - loss: 0.9729 - val_acc: 0.6886 - val_loss: 0.7243
# Epoch 41/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 98s 858ms/step - acc: 0.6040 - loss: 0.9374 - val_acc: 0.6952 - val_loss: 0.7160
# Epoch 42/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 98s 855ms/step - acc: 0.5636 - loss: 0.9922 - val_acc: 0.6969 - val_loss: 0.7125
# Epoch 43/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 98s 859ms/step - acc: 0.6062 - loss: 0.9230 - val_acc: 0.7051 - val_loss: 0.7060
# Epoch 44/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 97s 851ms/step - acc: 0.6201 - loss: 0.9108 - val_acc: 0.7051 - val_loss: 0.7017
# Epoch 45/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 97s 854ms/step - acc: 0.6069 - loss: 0.9284 - val_acc: 0.7068 - val_loss: 0.6965
# Epoch 46/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 97s 852ms/step - acc: 0.5848 - loss: 0.9648 - val_acc: 0.7084 - val_loss: 0.6922
# Epoch 47/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 98s 856ms/step - acc: 0.5971 - loss: 0.9400 - val_acc: 0.7100 - val_loss: 0.6880
# Epoch 48/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 98s 858ms/step - acc: 0.6194 - loss: 0.9018 - val_acc: 0.7092 - val_loss: 0.6846
# Epoch 49/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 99s 871ms/step - acc: 0.6091 - loss: 0.8978 - val_acc: 0.7125 - val_loss: 0.6800
# Epoch 50/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 96s 845ms/step - acc: 0.6351 - loss: 0.8948 - val_acc: 0.7175 - val_loss: 0.6732
# Epoch 51/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 98s 856ms/step - acc: 0.6051 - loss: 0.9241 - val_acc: 0.7191 - val_loss: 0.6703
# Epoch 52/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 97s 848ms/step - acc: 0.6149 - loss: 0.8997 - val_acc: 0.7208 - val_loss: 0.6650
# Epoch 53/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 97s 851ms/step - acc: 0.6196 - loss: 0.9001 - val_acc: 0.7216 - val_loss: 0.6634
# Epoch 54/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 96s 843ms/step - acc: 0.6394 - loss: 0.8833 - val_acc: 0.7241 - val_loss: 0.6596
# Epoch 55/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 101s 888ms/step - acc: 0.6163 - loss: 0.8912 - val_acc: 0.7257 - val_loss: 0.6536
# Epoch 56/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 98s 856ms/step - acc: 0.6246 - loss: 0.8758 - val_acc: 0.7241 - val_loss: 0.6509
# Epoch 57/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 96s 839ms/step - acc: 0.6292 - loss: 0.8858 - val_acc: 0.7273 - val_loss: 0.6480
# Epoch 58/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 97s 847ms/step - acc: 0.6266 - loss: 0.8814 - val_acc: 0.7282 - val_loss: 0.6423
# Epoch 59/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 99s 870ms/step - acc: 0.6469 - loss: 0.8532 - val_acc: 0.7282 - val_loss: 0.6386
# Epoch 60/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 99s 865ms/step - acc: 0.6448 - loss: 0.8625 - val_acc: 0.7323 - val_loss: 0.6380
# Epoch 61/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 99s 870ms/step - acc: 0.6467 - loss: 0.8287 - val_acc: 0.7323 - val_loss: 0.6331
# Epoch 62/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 90s 791ms/step - acc: 0.6349 - loss: 0.8664 - val_acc: 0.7339 - val_loss: 0.6301
# Epoch 63/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 97s 854ms/step - acc: 0.6426 - loss: 0.8477 - val_acc: 0.7364 - val_loss: 0.6286
# Epoch 64/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 89s 778ms/step - acc: 0.6506 - loss: 0.8503 - val_acc: 0.7381 - val_loss: 0.6234
# Epoch 65/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 87s 764ms/step - acc: 0.6577 - loss: 0.8310 - val_acc: 0.7372 - val_loss: 0.6222
# Epoch 66/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 86s 753ms/step - acc: 0.6562 - loss: 0.8303 - val_acc: 0.7381 - val_loss: 0.6202
# Epoch 67/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 86s 750ms/step - acc: 0.6697 - loss: 0.8081 - val_acc: 0.7381 - val_loss: 0.6154
# Epoch 68/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 87s 763ms/step - acc: 0.6606 - loss: 0.8412 - val_acc: 0.7405 - val_loss: 0.6129
# Epoch 69/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 93s 811ms/step - acc: 0.6516 - loss: 0.8226 - val_acc: 0.7414 - val_loss: 0.6114
# Epoch 70/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 90s 792ms/step - acc: 0.6637 - loss: 0.8188 - val_acc: 0.7414 - val_loss: 0.6122
# Epoch 71/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 92s 804ms/step - acc: 0.6684 - loss: 0.7975 - val_acc: 0.7446 - val_loss: 0.6035
# Epoch 72/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 92s 807ms/step - acc: 0.6776 - loss: 0.7780 - val_acc: 0.7455 - val_loss: 0.6034
# Epoch 73/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 96s 842ms/step - acc: 0.6708 - loss: 0.7924 - val_acc: 0.7471 - val_loss: 0.5971
# Epoch 74/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 91s 801ms/step - acc: 0.6520 - loss: 0.8174 - val_acc: 0.7471 - val_loss: 0.5970
# Epoch 75/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 93s 813ms/step - acc: 0.6739 - loss: 0.7878 - val_acc: 0.7488 - val_loss: 0.5949
# Epoch 76/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 837ms/step - acc: 0.6621 - loss: 0.7898 - val_acc: 0.7512 - val_loss: 0.5908
# Epoch 77/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 91s 797ms/step - acc: 0.6932 - loss: 0.7469 - val_acc: 0.7521 - val_loss: 0.5887
# Epoch 78/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 824ms/step - acc: 0.6663 - loss: 0.8049 - val_acc: 0.7512 - val_loss: 0.5883
# Epoch 79/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 821ms/step - acc: 0.6883 - loss: 0.7799 - val_acc: 0.7529 - val_loss: 0.5850
# Epoch 80/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 91s 801ms/step - acc: 0.6814 - loss: 0.7474 - val_acc: 0.7545 - val_loss: 0.5818
# Epoch 81/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 92s 803ms/step - acc: 0.6768 - loss: 0.7780 - val_acc: 0.7537 - val_loss: 0.5828
# Epoch 82/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 823ms/step - acc: 0.6792 - loss: 0.7729 - val_acc: 0.7545 - val_loss: 0.5785
# Epoch 83/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 831ms/step - acc: 0.6847 - loss: 0.7506 - val_acc: 0.7545 - val_loss: 0.5774
# Epoch 84/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 97s 851ms/step - acc: 0.6836 - loss: 0.7751 - val_acc: 0.7562 - val_loss: 0.5761
# Epoch 85/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 112s 982ms/step - acc: 0.6998 - loss: 0.7392 - val_acc: 0.7562 - val_loss: 0.5766
# Epoch 86/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 103s 905ms/step - acc: 0.7078 - loss: 0.7067 - val_acc: 0.7586 - val_loss: 0.5696
# Epoch 87/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 93s 818ms/step - acc: 0.6891 - loss: 0.7419 - val_acc: 0.7554 - val_loss: 0.5702
# Epoch 88/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 111s 976ms/step - acc: 0.6690 - loss: 0.7467 - val_acc: 0.7554 - val_loss: 0.5688
# Epoch 89/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 112s 983ms/step - acc: 0.6834 - loss: 0.7461 - val_acc: 0.7562 - val_loss: 0.5669
# Epoch 90/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 99s 867ms/step - acc: 0.6904 - loss: 0.7478 - val_acc: 0.7586 - val_loss: 0.5634
# Epoch 91/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 101s 888ms/step - acc: 0.6950 - loss: 0.7513 - val_acc: 0.7603 - val_loss: 0.5608
# Epoch 92/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 88s 769ms/step - acc: 0.7003 - loss: 0.7483 - val_acc: 0.7619 - val_loss: 0.5583
# Epoch 93/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 87s 763ms/step - acc: 0.7006 - loss: 0.7223 - val_acc: 0.7595 - val_loss: 0.5595
# Epoch 94/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 88s 767ms/step - acc: 0.7003 - loss: 0.7548 - val_acc: 0.7603 - val_loss: 0.5574
# Epoch 95/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 89s 778ms/step - acc: 0.7052 - loss: 0.7328 - val_acc: 0.7603 - val_loss: 0.5563
# Epoch 96/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 826ms/step - acc: 0.6888 - loss: 0.7313 - val_acc: 0.7611 - val_loss: 0.5535
# Epoch 97/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 98s 860ms/step - acc: 0.7170 - loss: 0.7162 - val_acc: 0.7603 - val_loss: 0.5545
# Epoch 98/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 98s 855ms/step - acc: 0.7016 - loss: 0.7249 - val_acc: 0.7628 - val_loss: 0.5511
# Epoch 99/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 99s 869ms/step - acc: 0.6848 - loss: 0.7525 - val_acc: 0.7652 - val_loss: 0.5480
# Epoch 100/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 100s 875ms/step - acc: 0.7088 - loss: 0.7164 - val_acc: 0.7661 - val_loss: 0.5459
# Epoch 101/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 102s 891ms/step - acc: 0.7046 - loss: 0.7246 - val_acc: 0.7652 - val_loss: 0.5454
# Epoch 102/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 98s 857ms/step - acc: 0.7038 - loss: 0.7137 - val_acc: 0.7652 - val_loss: 0.5460
# Epoch 103/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 101s 882ms/step - acc: 0.7155 - loss: 0.6908 - val_acc: 0.7677 - val_loss: 0.5447
# Epoch 104/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 97s 850ms/step - acc: 0.7010 - loss: 0.7054 - val_acc: 0.7694 - val_loss: 0.5417
# Epoch 105/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 825ms/step - acc: 0.7060 - loss: 0.7062 - val_acc: 0.7694 - val_loss: 0.5397
# Epoch 106/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 93s 815ms/step - acc: 0.7231 - loss: 0.6772 - val_acc: 0.7694 - val_loss: 0.5393
# Epoch 107/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 92s 809ms/step - acc: 0.7083 - loss: 0.7085 - val_acc: 0.7702 - val_loss: 0.5362
# Epoch 108/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 87s 760ms/step - acc: 0.7065 - loss: 0.6874 - val_acc: 0.7710 - val_loss: 0.5362
# Epoch 109/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 88s 769ms/step - acc: 0.7201 - loss: 0.7047 - val_acc: 0.7768 - val_loss: 0.5318
# Epoch 110/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 87s 763ms/step - acc: 0.7127 - loss: 0.6960 - val_acc: 0.7702 - val_loss: 0.5333
# Epoch 111/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 98s 854ms/step - acc: 0.7282 - loss: 0.6846 - val_acc: 0.7743 - val_loss: 0.5309
# Epoch 112/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 93s 812ms/step - acc: 0.7092 - loss: 0.7139 - val_acc: 0.7776 - val_loss: 0.5284
# Epoch 113/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 92s 806ms/step - acc: 0.7153 - loss: 0.6872 - val_acc: 0.7751 - val_loss: 0.5305
# Epoch 114/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 88s 770ms/step - acc: 0.7268 - loss: 0.6695 - val_acc: 0.7792 - val_loss: 0.5263
# Epoch 115/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 93s 813ms/step - acc: 0.7345 - loss: 0.6693 - val_acc: 0.7784 - val_loss: 0.5238
# Epoch 116/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 89s 780ms/step - acc: 0.7230 - loss: 0.6823 - val_acc: 0.7784 - val_loss: 0.5228
# Epoch 117/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 92s 804ms/step - acc: 0.7181 - loss: 0.6766 - val_acc: 0.7792 - val_loss: 0.5224
# Epoch 118/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 92s 808ms/step - acc: 0.7102 - loss: 0.6918 - val_acc: 0.7817 - val_loss: 0.5216
# Epoch 119/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 98s 856ms/step - acc: 0.7126 - loss: 0.7009 - val_acc: 0.7809 - val_loss: 0.5196
# Epoch 120/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 826ms/step - acc: 0.7248 - loss: 0.6746 - val_acc: 0.7825 - val_loss: 0.5171
# Epoch 121/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 93s 818ms/step - acc: 0.7324 - loss: 0.6648 - val_acc: 0.7842 - val_loss: 0.5172
# Epoch 122/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 834ms/step - acc: 0.7159 - loss: 0.6594 - val_acc: 0.7850 - val_loss: 0.5169
# Epoch 123/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 819ms/step - acc: 0.7288 - loss: 0.6825 - val_acc: 0.7834 - val_loss: 0.5169
# Epoch 124/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 833ms/step - acc: 0.7277 - loss: 0.6816 - val_acc: 0.7842 - val_loss: 0.5153
# Epoch 125/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 830ms/step - acc: 0.7368 - loss: 0.6617 - val_acc: 0.7867 - val_loss: 0.5118
# Epoch 126/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 818ms/step - acc: 0.7159 - loss: 0.6859 - val_acc: 0.7834 - val_loss: 0.5145
# Epoch 127/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 824ms/step - acc: 0.7307 - loss: 0.6600 - val_acc: 0.7867 - val_loss: 0.5116
# Epoch 128/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 828ms/step - acc: 0.7438 - loss: 0.6606 - val_acc: 0.7867 - val_loss: 0.5087
# Epoch 129/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 825ms/step - acc: 0.7364 - loss: 0.6553 - val_acc: 0.7883 - val_loss: 0.5064
# Epoch 130/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 93s 818ms/step - acc: 0.7189 - loss: 0.6849 - val_acc: 0.7883 - val_loss: 0.5081
# Epoch 131/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 820ms/step - acc: 0.7363 - loss: 0.6293 - val_acc: 0.7883 - val_loss: 0.5069
# Epoch 132/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 828ms/step - acc: 0.7266 - loss: 0.6614 - val_acc: 0.7883 - val_loss: 0.5039
# Epoch 133/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 827ms/step - acc: 0.7380 - loss: 0.6420 - val_acc: 0.7891 - val_loss: 0.5018
# Epoch 134/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 93s 818ms/step - acc: 0.7389 - loss: 0.6335 - val_acc: 0.7900 - val_loss: 0.5020
# Epoch 135/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 824ms/step - acc: 0.7242 - loss: 0.6926 - val_acc: 0.7916 - val_loss: 0.5001
# Epoch 136/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 823ms/step - acc: 0.7203 - loss: 0.6702 - val_acc: 0.7941 - val_loss: 0.4980
# Epoch 137/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 93s 816ms/step - acc: 0.7429 - loss: 0.6386 - val_acc: 0.7941 - val_loss: 0.4986
# Epoch 138/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 825ms/step - acc: 0.7311 - loss: 0.6685 - val_acc: 0.7916 - val_loss: 0.4976
# Epoch 139/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 93s 818ms/step - acc: 0.7311 - loss: 0.6629 - val_acc: 0.7932 - val_loss: 0.4980
# Epoch 140/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 823ms/step - acc: 0.7393 - loss: 0.6417 - val_acc: 0.7965 - val_loss: 0.4947
# Epoch 141/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 828ms/step - acc: 0.7444 - loss: 0.6294 - val_acc: 0.7965 - val_loss: 0.4934
# Epoch 142/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 826ms/step - acc: 0.7444 - loss: 0.6136 - val_acc: 0.7974 - val_loss: 0.4933
# Epoch 143/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 825ms/step - acc: 0.7370 - loss: 0.6555 - val_acc: 0.7990 - val_loss: 0.4916
# Epoch 144/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 826ms/step - acc: 0.7349 - loss: 0.6423 - val_acc: 0.7974 - val_loss: 0.4906
# Epoch 145/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 93s 817ms/step - acc: 0.7416 - loss: 0.6301 - val_acc: 0.7990 - val_loss: 0.4910
# Epoch 146/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 823ms/step - acc: 0.7339 - loss: 0.6448 - val_acc: 0.7998 - val_loss: 0.4901
# Epoch 147/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 825ms/step - acc: 0.7268 - loss: 0.6388 - val_acc: 0.8023 - val_loss: 0.4870
# Epoch 148/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 97s 847ms/step - acc: 0.7383 - loss: 0.6431 - val_acc: 0.7974 - val_loss: 0.4848
# Epoch 149/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 98s 861ms/step - acc: 0.7567 - loss: 0.6166 - val_acc: 0.7998 - val_loss: 0.4830
# Epoch 150/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 822ms/step - acc: 0.7457 - loss: 0.6365 - val_acc: 0.8015 - val_loss: 0.4829
# Epoch 151/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 92s 808ms/step - acc: 0.7654 - loss: 0.6055 - val_acc: 0.8015 - val_loss: 0.4834
# Epoch 152/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 825ms/step - acc: 0.7443 - loss: 0.6277 - val_acc: 0.8023 - val_loss: 0.4836
# Epoch 153/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 93s 813ms/step - acc: 0.7509 - loss: 0.6162 - val_acc: 0.8023 - val_loss: 0.4802
# Epoch 154/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 92s 807ms/step - acc: 0.7496 - loss: 0.6139 - val_acc: 0.8031 - val_loss: 0.4802
# Epoch 155/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 91s 794ms/step - acc: 0.7549 - loss: 0.5931 - val_acc: 0.8023 - val_loss: 0.4814
# Epoch 156/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 93s 811ms/step - acc: 0.7579 - loss: 0.6242 - val_acc: 0.8048 - val_loss: 0.4785
# Epoch 157/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 92s 806ms/step - acc: 0.7351 - loss: 0.6381 - val_acc: 0.8056 - val_loss: 0.4784
# Epoch 158/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 91s 802ms/step - acc: 0.7505 - loss: 0.6186 - val_acc: 0.8023 - val_loss: 0.4803
# Epoch 159/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 93s 815ms/step - acc: 0.7461 - loss: 0.6307 - val_acc: 0.8048 - val_loss: 0.4762
# Epoch 160/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 833ms/step - acc: 0.7394 - loss: 0.6259 - val_acc: 0.8081 - val_loss: 0.4732
# Epoch 161/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 832ms/step - acc: 0.7563 - loss: 0.6263 - val_acc: 0.8081 - val_loss: 0.4732
# Epoch 162/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 96s 839ms/step - acc: 0.7557 - loss: 0.6161 - val_acc: 0.8072 - val_loss: 0.4723
# Epoch 163/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 96s 837ms/step - acc: 0.7474 - loss: 0.6093 - val_acc: 0.8081 - val_loss: 0.4714
# Epoch 164/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 836ms/step - acc: 0.7573 - loss: 0.5907 - val_acc: 0.8072 - val_loss: 0.4707
# Epoch 165/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 832ms/step - acc: 0.7662 - loss: 0.6059 - val_acc: 0.8072 - val_loss: 0.4705
# Epoch 166/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 834ms/step - acc: 0.7448 - loss: 0.6222 - val_acc: 0.8081 - val_loss: 0.4678
# Epoch 167/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 833ms/step - acc: 0.7564 - loss: 0.5919 - val_acc: 0.8105 - val_loss: 0.4671
# Epoch 168/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 96s 839ms/step - acc: 0.7547 - loss: 0.5965 - val_acc: 0.8097 - val_loss: 0.4668
# Epoch 169/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 96s 842ms/step - acc: 0.7509 - loss: 0.6021 - val_acc: 0.8089 - val_loss: 0.4677
# Epoch 170/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 831ms/step - acc: 0.7560 - loss: 0.6144 - val_acc: 0.8081 - val_loss: 0.4678
# Epoch 171/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 96s 836ms/step - acc: 0.7626 - loss: 0.6058 - val_acc: 0.8097 - val_loss: 0.4638
# Epoch 172/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 826ms/step - acc: 0.7689 - loss: 0.5880 - val_acc: 0.8105 - val_loss: 0.4639
# Epoch 173/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 96s 836ms/step - acc: 0.7572 - loss: 0.6091 - val_acc: 0.8097 - val_loss: 0.4632
# Epoch 174/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 96s 837ms/step - acc: 0.7575 - loss: 0.6122 - val_acc: 0.8122 - val_loss: 0.4630
# Epoch 175/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 835ms/step - acc: 0.7473 - loss: 0.6167 - val_acc: 0.8097 - val_loss: 0.4628
# Epoch 176/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 829ms/step - acc: 0.7396 - loss: 0.6049 - val_acc: 0.8089 - val_loss: 0.4639
# Epoch 177/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 836ms/step - acc: 0.7543 - loss: 0.6179 - val_acc: 0.8105 - val_loss: 0.4602
# Epoch 178/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 835ms/step - acc: 0.7637 - loss: 0.5962 - val_acc: 0.8122 - val_loss: 0.4592
# Epoch 179/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 96s 841ms/step - acc: 0.7548 - loss: 0.6195 - val_acc: 0.8114 - val_loss: 0.4561
# Epoch 180/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 830ms/step - acc: 0.7520 - loss: 0.6010 - val_acc: 0.8114 - val_loss: 0.4600
# Epoch 181/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 825ms/step - acc: 0.7640 - loss: 0.6048 - val_acc: 0.8138 - val_loss: 0.4600
# Epoch 182/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 836ms/step - acc: 0.7502 - loss: 0.6336 - val_acc: 0.8122 - val_loss: 0.4560
# Epoch 183/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 834ms/step - acc: 0.7696 - loss: 0.5758 - val_acc: 0.8122 - val_loss: 0.4558
# Epoch 184/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 835ms/step - acc: 0.7536 - loss: 0.6005 - val_acc: 0.8130 - val_loss: 0.4545
# Epoch 185/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 141s 826ms/step - acc: 0.7607 - loss: 0.5897 - val_acc: 0.8130 - val_loss: 0.4546
# Epoch 186/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 832ms/step - acc: 0.7636 - loss: 0.5980 - val_acc: 0.8130 - val_loss: 0.4515
# Epoch 187/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 825ms/step - acc: 0.7535 - loss: 0.5802 - val_acc: 0.8130 - val_loss: 0.4522
# Epoch 188/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 833ms/step - acc: 0.7606 - loss: 0.5909 - val_acc: 0.8147 - val_loss: 0.4513
# Epoch 189/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 826ms/step - acc: 0.7636 - loss: 0.5786 - val_acc: 0.8138 - val_loss: 0.4523
# Epoch 190/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 825ms/step - acc: 0.7771 - loss: 0.5815 - val_acc: 0.8163 - val_loss: 0.4515
# Epoch 191/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 96s 837ms/step - acc: 0.7594 - loss: 0.5752 - val_acc: 0.8163 - val_loss: 0.4506
# Epoch 192/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 833ms/step - acc: 0.7621 - loss: 0.5696 - val_acc: 0.8163 - val_loss: 0.4474
# Epoch 193/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 822ms/step - acc: 0.7745 - loss: 0.5516 - val_acc: 0.8171 - val_loss: 0.4490
# Epoch 194/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 823ms/step - acc: 0.7653 - loss: 0.5798 - val_acc: 0.8180 - val_loss: 0.4488
# Epoch 195/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 837ms/step - acc: 0.7667 - loss: 0.5798 - val_acc: 0.8171 - val_loss: 0.4479
# Epoch 196/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 832ms/step - acc: 0.7696 - loss: 0.5902 - val_acc: 0.8180 - val_loss: 0.4449
# Epoch 197/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 96s 842ms/step - acc: 0.7706 - loss: 0.5865 - val_acc: 0.8188 - val_loss: 0.4429
# Epoch 198/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 834ms/step - acc: 0.7691 - loss: 0.5839 - val_acc: 0.8196 - val_loss: 0.4420
# Epoch 199/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 833ms/step - acc: 0.7731 - loss: 0.5621 - val_acc: 0.8196 - val_loss: 0.4413
# Epoch 200/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 827ms/step - acc: 0.7570 - loss: 0.6340 - val_acc: 0.8180 - val_loss: 0.4414
# Epoch 201/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 96s 839ms/step - acc: 0.7788 - loss: 0.5470 - val_acc: 0.8180 - val_loss: 0.4423
# Epoch 202/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 820ms/step - acc: 0.7558 - loss: 0.5834 - val_acc: 0.8171 - val_loss: 0.4423
# Epoch 203/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 833ms/step - acc: 0.7748 - loss: 0.5514 - val_acc: 0.8188 - val_loss: 0.4412
# Epoch 204/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 96s 839ms/step - acc: 0.7747 - loss: 0.5485 - val_acc: 0.8196 - val_loss: 0.4394
# Epoch 205/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 831ms/step - acc: 0.7752 - loss: 0.5444 - val_acc: 0.8229 - val_loss: 0.4369
# Epoch 206/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 827ms/step - acc: 0.7824 - loss: 0.5588 - val_acc: 0.8204 - val_loss: 0.4379
# Epoch 207/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 833ms/step - acc: 0.7685 - loss: 0.5907 - val_acc: 0.8213 - val_loss: 0.4369
# Epoch 208/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 833ms/step - acc: 0.7798 - loss: 0.5686 - val_acc: 0.8221 - val_loss: 0.4368
# Epoch 209/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 834ms/step - acc: 0.7698 - loss: 0.5795 - val_acc: 0.8237 - val_loss: 0.4349
# Epoch 210/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 824ms/step - acc: 0.7700 - loss: 0.5898 - val_acc: 0.8237 - val_loss: 0.4365
# Epoch 211/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 832ms/step - acc: 0.7677 - loss: 0.5804 - val_acc: 0.8245 - val_loss: 0.4343
# Epoch 212/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 834ms/step - acc: 0.7857 - loss: 0.5373 - val_acc: 0.8221 - val_loss: 0.4348
# Epoch 213/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 833ms/step - acc: 0.7727 - loss: 0.5612 - val_acc: 0.8254 - val_loss: 0.4324
# Epoch 214/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 96s 838ms/step - acc: 0.7673 - loss: 0.5822 - val_acc: 0.8245 - val_loss: 0.4324
# Epoch 215/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 825ms/step - acc: 0.7748 - loss: 0.5704 - val_acc: 0.8245 - val_loss: 0.4324
# Epoch 216/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 831ms/step - acc: 0.7714 - loss: 0.5641 - val_acc: 0.8254 - val_loss: 0.4310
# Epoch 217/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 99s 864ms/step - acc: 0.7762 - loss: 0.5608 - val_acc: 0.8262 - val_loss: 0.4295
# Epoch 218/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 98s 859ms/step - acc: 0.7602 - loss: 0.5946 - val_acc: 0.8262 - val_loss: 0.4297
# Epoch 219/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 822ms/step - acc: 0.7703 - loss: 0.5561 - val_acc: 0.8262 - val_loss: 0.4305
# Epoch 220/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 830ms/step - acc: 0.7758 - loss: 0.5409 - val_acc: 0.8254 - val_loss: 0.4280
# Epoch 221/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 831ms/step - acc: 0.7657 - loss: 0.5634 - val_acc: 0.8270 - val_loss: 0.4266
# Epoch 222/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 823ms/step - acc: 0.7926 - loss: 0.5351 - val_acc: 0.8262 - val_loss: 0.4279
# Epoch 223/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 824ms/step - acc: 0.7633 - loss: 0.5835 - val_acc: 0.8262 - val_loss: 0.4267
# Epoch 224/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 828ms/step - acc: 0.7895 - loss: 0.5357 - val_acc: 0.8262 - val_loss: 0.4267
# Epoch 225/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 830ms/step - acc: 0.7691 - loss: 0.5546 - val_acc: 0.8262 - val_loss: 0.4264
# Epoch 226/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 829ms/step - acc: 0.7706 - loss: 0.5639 - val_acc: 0.8270 - val_loss: 0.4244
# Epoch 227/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 823ms/step - acc: 0.7842 - loss: 0.5480 - val_acc: 0.8270 - val_loss: 0.4256
# Epoch 228/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 828ms/step - acc: 0.7819 - loss: 0.5269 - val_acc: 0.8278 - val_loss: 0.4225
# Epoch 229/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 823ms/step - acc: 0.8003 - loss: 0.5187 - val_acc: 0.8270 - val_loss: 0.4231
# Epoch 230/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 820ms/step - acc: 0.7719 - loss: 0.5385 - val_acc: 0.8287 - val_loss: 0.4230
# Epoch 231/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 827ms/step - acc: 0.7861 - loss: 0.5321 - val_acc: 0.8287 - val_loss: 0.4218
# Epoch 232/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 829ms/step - acc: 0.7750 - loss: 0.5521 - val_acc: 0.8270 - val_loss: 0.4210
# Epoch 233/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 832ms/step - acc: 0.7851 - loss: 0.5359 - val_acc: 0.8328 - val_loss: 0.4178
# Epoch 234/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 825ms/step - acc: 0.7852 - loss: 0.5256 - val_acc: 0.8303 - val_loss: 0.4187
# Epoch 235/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 821ms/step - acc: 0.7931 - loss: 0.5253 - val_acc: 0.8295 - val_loss: 0.4190
# Epoch 236/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 831ms/step - acc: 0.7750 - loss: 0.5376 - val_acc: 0.8295 - val_loss: 0.4191
# Epoch 237/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 820ms/step - acc: 0.7907 - loss: 0.5409 - val_acc: 0.8295 - val_loss: 0.4197
# Epoch 238/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 93s 819ms/step - acc: 0.7715 - loss: 0.5762 - val_acc: 0.8295 - val_loss: 0.4183
# Epoch 239/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 831ms/step - acc: 0.7888 - loss: 0.5401 - val_acc: 0.8328 - val_loss: 0.4152
# Epoch 240/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 821ms/step - acc: 0.7723 - loss: 0.5478 - val_acc: 0.8311 - val_loss: 0.4165
# Epoch 241/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 821ms/step - acc: 0.7861 - loss: 0.5383 - val_acc: 0.8303 - val_loss: 0.4164
# Epoch 242/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 823ms/step - acc: 0.7856 - loss: 0.5405 - val_acc: 0.8303 - val_loss: 0.4163
# Epoch 243/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 94s 822ms/step - acc: 0.7853 - loss: 0.5166 - val_acc: 0.8303 - val_loss: 0.4156
# Epoch 244/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 830ms/step - acc: 0.7840 - loss: 0.5435 - val_acc: 0.8303 - val_loss: 0.4147
# Epoch 245/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 96s 840ms/step - acc: 0.7808 - loss: 0.5472 - val_acc: 0.8311 - val_loss: 0.4130
# Epoch 246/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 832ms/step - acc: 0.7874 - loss: 0.5286 - val_acc: 0.8328 - val_loss: 0.4141
# Epoch 247/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 95s 832ms/step - acc: 0.8007 - loss: 0.5306 - val_acc: 0.8328 - val_loss: 0.4126
# Epoch 248/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 96s 838ms/step - acc: 0.7971 - loss: 0.4923 - val_acc: 0.8336 - val_loss: 0.4118
# Epoch 249/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 96s 838ms/step - acc: 0.7870 - loss: 0.5456 - val_acc: 0.8344 - val_loss: 0.4114
# Epoch 250/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 96s 841ms/step - acc: 0.7817 - loss: 0.5446 - val_acc: 0.8369 - val_loss: 0.4082

# %%
model.save('./BestModel_WithDataAugmentation5_xray_114.keras')

# %%
keras.models.load_model('./BestModel_WithDataAugmentation5_xray_114.keras')
# Out:
# <Functional name=functional_2, built=True>

# %%
val_loss, val_acc = model.evaluate(validation_dataset)
print('val_acc:', val_acc)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 274ms/step - acc: 0.8302 - loss: 0.4281
# val_acc: 0.8369027972221375

# %%
import matplotlib.pyplot as plt
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.utils import to_categorical

# %%
# img = tf.keras.preprocessing.image.load_img('./train/cats/cat.1.jpg', target_size=(150, 150), interpolation='bilinear')
img = tf.keras.preprocessing.image.load_img('images/val/Tuberculosis/test_0_274.jpeg', target_size=(150, 150), interpolation='bilinear')
plt.imshow(img)
plt.show()
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)
print(img_array.shape)
result = model.predict(img_array)

# Convert prediction to class index (0, 1, 2)
class_index = np.argmax(result, axis=1)

# Convert class index to one-hot encoded vector
one_hot_prediction = to_categorical(class_index, num_classes=3)

# Print the result
print("Class index:", class_index)
print("One-hot encoded prediction:", one_hot_prediction)
# Out:
# (1, 150, 150, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# Class index: [2]
# One-hot encoded prediction: [[0. 0. 1.]]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report


# Inicializar listas para almacenar etiquetas verdaderas y predicciones
true_labels = []
predictions = []

# Iterar a través del conjunto de validación y predecir
for images, labels in validation_dataset:
    preds = model.predict(images)
    predictions.extend(preds)
    true_labels.extend(labels.numpy())

# Convertir las listas a arrays de numpy
predictions = np.array(predictions)
true_labels = np.array(true_labels)

# Si las etiquetas verdaderas están en formato one-hot encoded, convertirlas a etiquetas enteras
if true_labels.ndim == 2 and true_labels.shape[1] > 1:
    true_labels_int = np.argmax(true_labels, axis=1)
else:
    true_labels_int = true_labels

# Asegurarse de que las predicciones son probabilidades y luego convertirlas a etiquetas enteras
predictions_int = np.argmax(predictions, axis=1)

# Crear la matriz de confusión
cm = confusion_matrix(true_labels_int, predictions_int)

# Mostrar la matriz de confusión
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()

# Generar y mostrar el reporte de clasificación
report = classification_report(true_labels_int, predictions_int, target_names=validation_dataset.class_names)
print("Classification Report:\n", report)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Classification Report:
#                        precision    recall  f1-score   support
#
# Corona_Virus_Disease       0.80      0.82      0.81       406
#               Normal       0.83      0.98      0.90       402
#         Tuberculosis       0.90      0.71      0.79       406
#
#             accuracy                           0.84      1214
#            macro avg       0.84      0.84      0.83      1214
#         weighted avg       0.84      0.84      0.83      1214
